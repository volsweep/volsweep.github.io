# %% [markdown]
# # FEC Campaign Finance Analysis
#
# ## Candidate-Committee Linkages

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
year = '2018'

# %%
# read in candidate-committee linkage data
ccl = pd.read_csv(
    f'https://www.fec.gov/files/bulk-downloads/{year}/ccl{year[2:]}.zip',
    sep = '|', 
    error_bad_lines = False, 
    header = None, 
)

# read in column headers
headers = pd.read_csv(
    'https://www.fec.gov/files/bulk-downloads/data_dictionaries/ccl_header_file.csv', 
)

ccl.columns = [x.lower() for x in headers.columns]
print('original length:', len(ccl))

cand = pd.read_csv('data/01a_cand_clean.csv')
cands = list(set(cand['cand_id']))

ccl = ccl[ccl['cand_id'].apply(lambda x: x in cands)]
print(f'{year} cand_id:', len(ccl))

ccl = ccl[ccl['fec_election_yr'] == int(year)]
print('fec election year:', len(ccl))

ccl.drop(['fec_election_yr', 'linkage_id'], axis = 1, inplace = True)
cand_dict = dict(zip(cand['cand_id'], cand['cand_name']))
ccl['cand_name'] = [cand_dict[x] for x in ccl['cand_id']]

ccl.head()
# Out:
# original length: 7203
# 2018 cand_id: 1358
# fec election year: 1358
#      cand_id  cand_election_yr    cmte_id cmte_tp cmte_dsgn  \
# 0  H0AL02087              2018  C00493783       H         J
# 1  H0AL02087              2018  C00462143       H         P
# 4  H0AL05163              2018  C00464149       H         P
# 7  H0AL07086              2018  C00458976       H         P
# 9  H0AR01083              2018  C00462374       H         P
#
#                   cand_name
# 0              ROBY, MARTHA
# 1              ROBY, MARTHA
# 4                BROOKS, MO
# 7          SEWELL, TERRI A.
# 9  CRAWFORD, ERIC ALAN RICK

# %%
# confirm all entries in cand_id column are candidate IDs
ccl['cand_id'].apply(lambda x: x[0]).value_counts()
# Out:
# H    1017
# S     341
# Name: cand_id, dtype: int64

# %%
# check for nulls
ccl.isnull().sum()[ccl.isnull().sum() > 0].sort_values()
# Out:
# Series([], dtype: int64)

# %%
# 21 cand_ids appear twice in ccl dataframe
ccl.loc[
    ccl.duplicated(['cand_id', 'cmte_id', 'cmte_tp', 'cmte_dsgn'], keep = False), 
    'cand_id', 
].value_counts().value_counts()
# Out:
# 2    9
# 6    1
# 4    1
# Name: cand_id, dtype: int64

# %%
# display cand_ids shared at least three times across ccl rows
dupes = list(ccl.loc[
    ccl.duplicated(['cand_id', 'cmte_id', 'cmte_tp', 'cmte_dsgn'], keep = False), 
    'cand_id', 
].value_counts()[
    ccl.loc[
    ccl.duplicated(['cand_id', 'cmte_id', 'cmte_tp', 'cmte_dsgn'], keep = False), 
    'cand_id', 
].value_counts() > 2
].index)

for dupe in dupes:
    print(
        dupe, 
        cand.loc[cand['cand_id'] == dupe, 'cand_name'].values[0], 
        cand.loc[cand['cand_id'] == dupe, 'cand_ici'].values[0],
        cand.loc[cand['cand_id'] == dupe, 'contest'].values[0],
        cand.loc[cand['cand_id'] == dupe, 'cand_pty_affiliation'].values[0],
    )
    print(ccl.loc[ccl['cand_id'] == dupe, [
        'cand_election_yr', 
        'cmte_id', 
        'cmte_tp', 
        'cmte_dsgn', 
        'linkage_id',
    ]].sort_values(['cand_election_yr']))
    print('\n\n')
# Out:
# H8UT03238 CURTIS, JOHN I UT_03 Republican
#       cand_election_yr    cmte_id cmte_tp cmte_dsgn  linkage_id
# 4693              2017  C00647180       O         U         NaN
# 4694              2017  C00647339       H         P         NaN
# 4696              2017  C00654459       N         J         NaN
# 4691              2018  C00647339       H         P         NaN
# 4692              2018  C00647180       O         U         NaN
# 4695              2018  C00654459       N         J         NaN
#
#
#
# H8GA06286 HANDEL, KAREN CHRISTINE I GA_06 Republican
#       cand_election_yr    cmte_id cmte_tp cmte_dsgn  linkage_id
# 3144              2017  C00634949       H         A         NaN
# 3145              2017  C00633362       H         P         NaN
# 3146              2018  C00634949       H         A         NaN
# 3147              2018  C00633362       H         P         NaN

# %%
# how many times each cmte_id appears; 
# <# times> <count>
ccl['cmte_id'].value_counts().value_counts().sort_index()
# Out:
# 1     1065
# 2       61
# 3       12
# 4       12
# 5        1
# 6        1
# 8        3
# 11       1
# 12       1
# 13       1
# 16       1
# Name: cmte_id, dtype: int64

# %%
# quick timewarp from the next notebook to get the committee names for the next loop
cm = pd.read_csv(
    f'https://www.fec.gov/files/bulk-downloads/{year}/cm{year[2:]}.zip', 
    sep = '|', 
    error_bad_lines = False, 
    header = None, 
)
# add column headers from separate file
headers = pd.read_csv(
    'https://www.fec.gov/files/bulk-downloads/data_dictionaries/cm_header_file.csv', 
)
cm.columns = [x.lower() for x in headers.columns]
cm_dict = dict(zip(cm['cmte_id'], cm['cmte_nm']))
del cm

# %%
# display candidates pertaining to each cmte_id (name shown) appearing more than twice
multi_cand = list(ccl['cmte_id'].value_counts()[ccl['cmte_id'].value_counts() > 1].index)

print('list starts here')
print('\n')
for comm in multi_cand:
    cands = list(ccl.loc[ccl['cmte_id'] == comm, 'cand_id'].values)
    lil_cand = cand[cand['cand_id'].apply(lambda x: x in cands)]
    pty = list(set(lil_cand['cand_pty_affiliation']))
    lil_cand = lil_cand[[
        'cand_name', 
        'contest', 
        'cand_ici',
        
    ]].sort_values(['contest'], ascending = [True]).reset_index(drop = True)
    if len(lil_cand) > 2:
        print(cm_dict[comm], '(' + str(len(lil_cand)) + ', ' + str(pty) + ')')
        print(lil_cand, '\n\n')
# Out:
# list starts here
#
#
# BLUE SENATE 2018 (16, ['Democrat', 'Third party'])
#                         cand_name    contest cand_ici
# 0                 SINEMA, KYRSTEN  AZ_senate        O
# 1        MURPHY, CHRISTOPHER S MR  CT_senate        I
# 2                    NELSON, BILL  FL_senate        I
# 3              DONNELLY, JOSEPH S  IN_senate        I
# 4          KING, ANGUS STANLEY JR  ME_senate        I
# 5                STABENOW, DEBBIE  MI_senate        I
# 6                MENENDEZ, ROBERT  NJ_senate        I
# 7         HEINRICH, MARTIN TREVOR  NM_senate        I
# 8                    ROSEN, JACKY  NV_senate        C
# 9   GILLIBRAND, KIRSTEN ELIZABETH  NY_senate        I
# 10                 BROWN, SHERROD  OH_senate        I
# 11             CASEY, ROBERT P JR  PA_senate        I
# 12         KAINE, TIMOTHY MICHAEL  VA_senate        I
# 13                CANTWELL, MARIA  WA_senate        I
# 14                 BALDWIN, TAMMY  WI_senate        I
# 15               MANCHIN III, JOE  WV_senate        I
#
#
# WOMEN ON THE ROAD 2018 (13, ['Democrat'])
#                         cand_name            contest cand_ici
# 0                 SINEMA, KYRSTEN          AZ_senate        O
# 1               FEINSTEIN, DIANNE          CA_senate        I
# 2                 HIRONO, MAZIE K          HI_senate        I
# 3               WARREN, ELIZABETH          MA_senate        I
# 4                STABENOW, DEBBIE          MI_senate        I
# 5                  KLOBUCHAR, AMY          MN_senate        I
# 6                     SMITH, TINA  MN_senate_special        I
# 7               MCCASKILL, CLAIRE          MO_senate        I
# 8                 HEITKAMP, HEIDI          ND_senate        I
# 9                    ROSEN, JACKY          NV_senate        C
# 10  GILLIBRAND, KIRSTEN ELIZABETH          NY_senate        I
# 11                CANTWELL, MARIA          WA_senate        I
# 12                 BALDWIN, TAMMY          WI_senate        I
#
#
# FOUNDERS COMMITTEE; THE (12, ['Republican'])
#                    cand_name    contest cand_ici
# 0            MCSALLY, MARTHA  AZ_senate        O
# 1            SCOTT, RICK GOV  FL_senate        C
# 2                BRAUN, MIKE  IN_senate        C
# 3                JAMES, JOHN  MI_senate        C
# 4       HAWLEY, JOSHUA DAVID  MO_senate        C
# 5            ROSENDALE, MATT  MT_senate        C
# 6          CRAMER, KEVIN MR.  ND_senate        C
# 7              HUGIN, ROBERT  NJ_senate        C
# 8               HELLER, DEAN  NV_senate        I
# 9     BLACKBURN, MARSHA MRS.  TN_senate        O
# 10  CRUZ, RAFAEL EDWARD  TED  TX_senate        I
# 11      MORRISEY, PATRICK MR  WV_senate        C
#
#
# JUSTICE 2018 (11, ['Democrat'])
#              cand_name            contest cand_ici
# 0      SINEMA, KYRSTEN          AZ_senate        O
# 1         NELSON, BILL          FL_senate        I
# 2      HIRONO, MAZIE K          HI_senate        I
# 3   DONNELLY, JOSEPH S          IN_senate        I
# 4          SMITH, TINA  MN_senate_special        I
# 5    MCCASKILL, CLAIRE          MO_senate        I
# 6          TESTER, JON          MT_senate        I
# 7         ROSEN, JACKY          NV_senate        C
# 8   CASEY, ROBERT P JR          PA_senate        I
# 9     BREDESEN, PHILIP          TN_senate        O
# 10      BALDWIN, TAMMY          WI_senate        I
#
#
# HEALTH FIRST COMMITTEE (8, ['Republican'])
#                 cand_name contest cand_ici
# 0        BILIRAKIS, GUS M   FL_12        I
# 1      BROOKS, SUSAN MRS.   IN_05        I
# 2       BUCSHON, LARRY D.   IN_08        I
# 3  GUTHRIE, S. BRETT HON.   KY_02        I
# 4         LONG, BILLY MR.   MO_07        I
# 5          LANCE, LEONARD   NJ_07        I
# 6  COLLINS, CHRISTOPHER C   NY_27        I
# 7      GRIFFITH, H MORGAN   VA_09        I
#
#
# FRESHMAN AGRICULTURAL REPUBLICAN MEMBERS TRUST AKA FARM TRUST (8, ['Republican'])
#                   cand_name contest cand_ici
# 0              ROBY, MARTHA   AL_02        I
# 1  CRAWFORD, ERIC ALAN RICK   AR_01        I
# 2          TIPTON, SCOTT R.   CO_03        I
# 3       SCOTT, JAMES AUSTIN   GA_08        I
# 4           HULTGREN, RANDY   IL_14        I
# 5           HARTZLER, VICKY   MO_04        I
# 6             GIBBS, ROBERT   OH_07        I
# 7    DESJARLAIS, SCOTT HON.   TN_04        I
#
#
# PATRIOT DAY I 2015 (8, ['Republican'])
#              cand_name contest cand_ici
# 0       VALADAO, DAVID   CA_21        I
# 1  CURBELO, CARLOS MR.   FL_26        I
# 2         YOUNG, DAVID   IA_03        I
# 3        BOST, MICHAEL   IL_12        I
# 4    POLIQUIN, BRUCE L   ME_02        I
# 5        ZELDIN, LEE M   NY_01        I
# 6        KATKO, JOHN M   NY_24        I
# 7        HURD, WILLIAM   TX_23        I
#
#
# SENATE 2018 IMPACT (6, ['Democrat'])
#             cand_name    contest cand_ici
# 0        NELSON, BILL  FL_senate        I
# 1  DONNELLY, JOSEPH S  IN_senate        I
# 2   MCCASKILL, CLAIRE  MO_senate        I
# 3         TESTER, JON  MT_senate        I
# 4     HEITKAMP, HEIDI  ND_senate        I
# 5    MANCHIN III, JOE  WV_senate        I
#
#
# PROTECTING THE MAJORITY COMMITTEE (5, ['Republican'])
#               cand_name    contest cand_ici
# 0           BRAUN, MIKE  IN_senate        C
# 1  HAWLEY, JOSHUA DAVID  MO_senate        C
# 2     CRAMER, KEVIN MR.  ND_senate        C
# 3      FISCHER, DEBRA S  NE_senate        I
# 4          HELLER, DEAN  NV_senate        I
#
#
# COMMON SENSE 2018 (4, ['Democrat'])
#             cand_name    contest cand_ici
# 0        NELSON, BILL  FL_senate        I
# 1   MCCASKILL, CLAIRE  MO_senate        I
# 2      BROWN, SHERROD  OH_senate        I
# 3  CASEY, ROBERT P JR  PA_senate        I
#
#
# SENATE IMPACT 2018 (4, ['Democrat'])
#                   cand_name    contest cand_ici
# 0  MURPHY, CHRISTOPHER S MR  CT_senate        I
# 1        DONNELLY, JOSEPH S  IN_senate        I
# 2               TESTER, JON  MT_senate        I
# 3   HEINRICH, MARTIN TREVOR  NM_senate        I
#
#
# SENATE VICTORY 2018 (4, ['Democrat'])
#                 cand_name    contest cand_ici
# 0       FEINSTEIN, DIANNE  CA_senate        I
# 1            NELSON, BILL  FL_senate        I
# 2          KLOBUCHAR, AMY  MN_senate        I
# 3  WHITEHOUSE, SHELDON II  RI_senate        I
#
#
# GREEN SENATE IMPACT 2018 (4, ['Democrat'])
#             cand_name    contest cand_ici
# 0        NELSON, BILL  FL_senate        I
# 1         TESTER, JON  MT_senate        I
# 2  CASEY, ROBERT P JR  PA_senate        I
# 3      BALDWIN, TAMMY  WI_senate        I
#
#
# WINSOME LEADERS II (4, ['Republican'])
#                 cand_name    contest cand_ici
# 0    HAWLEY, JOSHUA DAVID  MO_senate        C
# 1       CRAMER, KEVIN MR.  ND_senate        C
# 2  BLACKBURN, MARSHA MRS.  TN_senate        O
# 3    MORRISEY, PATRICK MR  WV_senate        C
#
#
# SENATE IMPACT 2018 (4, ['Democrat'])
#                 cand_name    contest cand_ici
# 0       MCCASKILL, CLAIRE  MO_senate        I
# 1            ROSEN, JACKY  NV_senate        C
# 2  KAINE, TIMOTHY MICHAEL  VA_senate        I
# 3          BALDWIN, TAMMY  WI_senate        I
#
#
# 2018 SENATE IMPACT (4, ['Democrat'])
#                  cand_name    contest cand_ici
# 0             NELSON, BILL  FL_senate        I
# 1       DONNELLY, JOSEPH S  IN_senate        I
# 2             ROSEN, JACKY  NV_senate        C
# 3  O'ROURKE, ROBERT (BETO)  TX_senate        C
#
#
# STRENGTHEN THE SENATE MAJORITY 2018 (4, ['Republican'])
#               cand_name    contest cand_ici
# 0       MCSALLY, MARTHA  AZ_senate        O
# 1           BRAUN, MIKE  IN_senate        C
# 2  HAWLEY, JOSHUA DAVID  MO_senate        C
# 3  MORRISEY, PATRICK MR  WV_senate        C
#
#
# GREEN SENATE IMPACT 2018 (4, ['Democrat'])
#           cand_name            contest cand_ici
# 0   SINEMA, KYRSTEN          AZ_senate        O
# 1  STABENOW, DEBBIE          MI_senate        I
# 2       SMITH, TINA  MN_senate_special        I
# 3      ROSEN, JACKY          NV_senate        C
#
#
# ENCOURAGING LEARNING AND SKILLS PAC (4, ['Republican'])
#                     cand_name contest cand_ici
# 0  FERGUSON, ANDERSON DREW IV   GA_03        I
# 1          MITCHELL, PAUL III   MI_10        I
# 2       LEWIS, JASON MARK MR.   MN_02        I
# 3          FOXX, VIRGINIA ANN   NC_05        I
#
#
# REPUBLICANS INSPIRING SUCCESS & EMPOWERMENT PROJECT (RISE PROJECT) (4, ['Republican'])
#             cand_name contest cand_ici
# 0       WALTERS, MIMI   CA_45        I
# 1  STEFANIK, ELISE M.   NY_21        I
# 2           LOVE, MIA   UT_04        I
# 3   COMSTOCK, BARBARA   VA_10        I
#
#
# TEXANS FOR A PROGRESSIVE SENATE (4, ['Democrat'])
#            cand_name    contest cand_ici
# 0   STABENOW, DEBBIE  MI_senate        I
# 1     KLOBUCHAR, AMY  MN_senate        I
# 2  MCCASKILL, CLAIRE  MO_senate        I
# 3     BALDWIN, TAMMY  WI_senate        I
#
#
# MN OH PA VICTORY FUND (3, ['Democrat'])
#             cand_name    contest cand_ici
# 0      KLOBUCHAR, AMY  MN_senate        I
# 1      BROWN, SHERROD  OH_senate        I
# 2  CASEY, ROBERT P JR  PA_senate        I
#
#
# AMC FUND (3, ['Democrat'])
#                     cand_name contest cand_ici
# 0  SHERRILL, REBECCA MICHELLE   NJ_11        O
# 1           HOULAHAN, CHRISSY   PA_06        O
# 2         SPANBERGER, ABIGAIL   VA_07        C
#
#
# PROTECT THE SENATE 2018 (3, ['Republican'])
#           cand_name    contest cand_ici
# 0   WICKER, ROGER F  MS_senate        I
# 1  FISCHER, DEBRA S  NE_senate        I
# 2      HELLER, DEAN  NV_senate        I
#
#
# KEEP THE MAJORITY (3, ['Republican'])
#            cand_name            contest cand_ici
# 0     HOUSLEY, KARIN  MN_senate_special        C
# 1  CRAMER, KEVIN MR.          ND_senate        C
# 2       HELLER, DEAN          NV_senate        I
#
#
# WOMEN ON THE ROAD SEATTLE 2018 (3, ['Democrat'])
#          cand_name            contest cand_ici
# 0      SMITH, TINA  MN_senate_special        I
# 1     ROSEN, JACKY          NV_senate        C
# 2  CANTWELL, MARIA          WA_senate        I
#
#
# SECURE THE HEARTLAND FUND (3, ['Democrat'])
#          cand_name    contest cand_ici
# 0   KLOBUCHAR, AMY  MN_senate        I
# 1  HEITKAMP, HEIDI  ND_senate        I
# 2   BALDWIN, TAMMY  WI_senate        I
#
#
# GROW THE MAJORITY (3, ['Republican'])
#               cand_name    contest cand_ici
# 0       MCSALLY, MARTHA  AZ_senate        O
# 1           BRAUN, MIKE  IN_senate        C
# 2  MORRISEY, PATRICK MR  WV_senate        C
#
#
# FOUR AMIGOS JOINT COMMITTEE; THE (3, ['Republican'])
#           cand_name contest cand_ici
# 0   MCCARTHY, KEVIN   CA_23        I
# 1     ROSKAM, PETER   IL_06        I
# 2  JORDAN, JAMES D.   OH_04        I
#
#
# KEEP THE SENATE RED 2018 (3, ['Republican'])
#                 cand_name    contest cand_ici
# 0             BRAUN, MIKE  IN_senate        C
# 1       CRAMER, KEVIN MR.  ND_senate        C
# 2  BLACKBURN, MARSHA MRS.  TN_senate        O
#
#
# WOMEN ON THE ROAD CALIFORNIA 2018 (3, ['Democrat'])
#            cand_name    contest cand_ici
# 0  FEINSTEIN, DIANNE  CA_senate        I
# 1    HIRONO, MAZIE K  HI_senate        I
# 2    CANTWELL, MARIA  WA_senate        I
#
#
# WINSOME LEADERS I (3, ['Republican'])
#                 cand_name    contest cand_ici
# 0    HAWLEY, JOSHUA DAVID  MO_senate        C
# 1  BLACKBURN, MARSHA MRS.  TN_senate        O
# 2    MORRISEY, PATRICK MR  WV_senate        C
#
#
# UPPER MIDWEST WOMEN VICTORY FUND (3, ['Democrat'])
#           cand_name    contest cand_ici
# 0  STABENOW, DEBBIE  MI_senate        I
# 1    KLOBUCHAR, AMY  MN_senate        I
# 2    BALDWIN, TAMMY  WI_senate        I

# %% [markdown]
# ### Make readable

# %%
# committee type
cmtetp_dict = {
    'H' : 'cmte_House',
    'S' : 'cmte_Senate',
    'N' : 'cmte_PACnonqual',
    'Q' : 'cmte_PACqual',
    'Y' : 'cmte_Partyqual',
    'O' : 'cmte_SuperPAC',
    'U' : 'cmte_Singlecand',
    'P' : 'cmte_President', 
    'I' : 'cmte_IndepExpenditor', 
    'D' : 'cmte_DelegateCommittee',
    'X' : 'cmte_Partynonqual', 
    'V' : 'cmte_PACnoncontribnonqual', 
}

ccl['cmte_tp'] = [cmtetp_dict[x] for x in ccl['cmte_tp']]
ccl['cmte_tp'].value_counts()
# Out:
# cmte_House         926
# cmte_Senate        261
# cmte_PACnonqual    155
# cmte_PACqual         6
# cmte_Partyqual       5
# cmte_SuperPAC        4
# cmte_Singlecand      1
# Name: cmte_tp, dtype: int64

# %%
# committee designation
cmtedsgn_dict = {
    'A' : 'Authorized by a candidate',
    'B' : 'Lobbyist/Registrant PAC',
    'D' : 'Leadership PAC',
    'J' : 'Joint fundraiser',
    'P' : 'Principal campaign committee',
    'U' : 'Unauthorized',
    np.nan : np.nan, 
    
}

ccl['cmte_dsgn'] = [cmtedsgn_dict[x] for x in ccl['cmte_dsgn']]
ccl['cmte_dsgn'].value_counts()
# Out:
# Principal campaign committee    952
# Joint fundraiser                371
# Authorized by a candidate        23
# Unauthorized                      9
# Leadership PAC                    3
# Name: cmte_dsgn, dtype: int64

# %%
ccl.loc[
    ccl['cmte_dsgn'] == 'Principal campaign committee',
    'cmte_tp'].value_counts()
# Out:
# cmte_House     869
# cmte_Senate     83
# Name: cmte_tp, dtype: int64

# %%
pccs = ccl.loc[
    ccl['cmte_dsgn'] == 'Principal campaign committee', 
    ['cand_id', 'cmte_id']
]

pccs
# Out:
#         cand_id    cmte_id
# 1     H0AL02087  C00462143
# 4     H0AL05163  C00464149
# 7     H0AL07086  C00458976
# 9     H0AR01083  C00462374
# 16    H0AR03055  C00477745
# ...         ...        ...
# 7160  S8WA00194  C00349506
# 7177  S8WA00319  C00681569
# 7187  S8WI00224  C00655522
# 7193  S8WV00143  C00651075
# 7201  S8WY00189  C00663146
#
# [952 rows x 2 columns]

# %%
pccs.to_csv('data/02a_principalcampaigncommittees.csv', index = False)

# %%
# add linkage count column to cand dataframe
links_df = pd.DataFrame(ccl['cand_id'].value_counts())
links_df.reset_index(drop = False, inplace = True)
links_df.columns = ['cand_id', 'cm_links']
links_dict = dict(zip(links_df['cand_id'], links_df['cm_links']))
cand['cm_links'] = [links_dict[cand.loc[i, 'cand_id']] if \
                    (cand.loc[i, 'cand_id'] in list(links_dict.keys())) else \
                    0 for i in list(cand.index)]

cand['cm_links'].value_counts().sort_index()
# Out:
# 1     765
# 2     102
# 3      33
# 4       8
# 5       3
# 6       4
# 7       8
# 8       3
# 9       1
# 11      4
# 12      4
# 18      1
# 20      1
# Name: cm_links, dtype: int64

# %%
cand[cand['cm_links'] == 0]
# Out:
# Empty DataFrame
# Columns: [cand_id, cand_name, cand_ici, cand_pty_affiliation, ttl_receipts, trans_from_auth, ttl_disb, trans_to_auth, coh_bop, coh_cop, cand_contrib, cand_loans, other_loans, cand_loan_repay, other_loan_repay, debts_owed_by, ttl_indiv_contrib, cand_office_st, cand_office_district, other_pol_cmte_contrib, pol_pty_contrib, cvg_end_dt, indiv_refunds, cmte_refunds, position, contest, type, state, cm_links]
# Index: []
#
# [0 rows x 29 columns]

# %%
cand[cand['cm_links'] > 10].sort_values(['cand_name'])
# Out:
#       cand_id           cand_name cand_ici cand_pty_affiliation  ttl_receipts  \
# 7   S2WI00219      BALDWIN, TAMMY        I             Democrat   27758852.65
# 11  S6OH00163      BROWN, SHERROD        I             Democrat   22766559.45
# 21  S2IN00091  DONNELLY, JOSEPH S        I             Democrat   14585917.72
# 6   S2ND00099     HEITKAMP, HEIDI        I             Democrat   29525599.65
# 50  S6MN00267      KLOBUCHAR, AMY        I             Democrat    8132759.12
# 3   S6MO00305   MCCASKILL, CLAIRE        I             Democrat   37714657.65
# 5   S8FL00166        NELSON, BILL        I             Democrat   32401758.29
# 8   S8NV00156        ROSEN, JACKY        C             Democrat   26242152.35
# 24  S8MI00281    STABENOW, DEBBIE        I             Democrat   13467045.34
# 15  S6MT00162         TESTER, JON        I             Democrat   18686615.43
#
#     trans_from_auth     ttl_disb  trans_to_auth     coh_bop     coh_cop  ...  \
# 7        1490494.35  28706579.25      129500.00  1089919.00   142193.20  ...
# 11       2734077.17  24579168.77           0.00  3183855.00  1371245.26  ...
# 21       1203398.13  15800916.06           0.00  1388871.00   173872.55  ...
# 6         975830.43  23660193.94           0.00   618450.00  6483856.47  ...
# 50        587503.52   6941152.26           0.00  1881667.00  3935476.60  ...
# 3        2963215.80  38254849.68         200.00   781519.00   241328.55  ...
# 5        1130542.67  32418265.69           0.00  1745453.00  1730969.24  ...
# 8        1834737.92  26079221.37           0.00    15260.89   178189.86  ...
# 24        954331.75  14887956.20         913.92  3203218.13  1782307.27  ...
# 15       1190926.45  19757019.91           0.00  1550978.00   480573.87  ...
#
#     other_pol_cmte_contrib  pol_pty_contrib  cvg_end_dt  indiv_refunds  \
# 7               1881644.77           100.00  2018-12-01      343163.38
# 11              2552879.50             0.00  2018-12-01      242444.34
# 21              2704788.58         57400.00  2018-12-01       42229.81
# 6               2920093.62          1000.00  2018-12-01      459514.53
# 50              1493360.13          5000.00  2018-12-01       65319.48
# 3               2401313.57             0.00  2018-12-01      452202.29
# 5               2505695.19          2000.00  2018-12-01      168685.66
# 8               1271587.99         48296.95  2018-12-01      437310.08
# 24              2876408.28         48400.00  2018-12-01      207652.85
# 15              2417939.00             0.00  2018-12-01      214397.53
#
#     cmte_refunds  position    contest      type  state  cm_links
# 7       35150.00         S  WI_senate  Group 02     WI        20
# 11      16550.00         S  OH_senate  Group 02     OH        11
# 21      16921.17         S  IN_senate  Group 10     IN        11
# 6       21800.00         S  ND_senate  Group 02     ND        11
# 50      18500.00         S  MN_senate  Group 02     MN        11
# 3       12500.00         S  MO_senate  Group 02     MO        18
# 5        6500.00         S  FL_senate  Group 10     FL        12
# 8         530.00         S  NV_senate  Group 04     NV        12
# 24      40921.00         S  MI_senate  Group 02     MI        12
# 15       1500.00         S  MT_senate  Group 02     MT        12
#
# [10 rows x 29 columns]

# %%
ccl.to_csv('data/02a_cand_comm_linkages.csv', index = False)

# %%
cand.to_csv('data/02a_cand_clean.csv', index = False)
