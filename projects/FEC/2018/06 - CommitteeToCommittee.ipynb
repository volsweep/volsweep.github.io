# %%
import pandas as pd
import numpy as np

# %%
year = '2018'

# %%
# add column headers from separate file
headers = pd.read_csv(
    f'https://www.fec.gov/files/bulk-downloads/data_dictionaries/oth_header_file.csv',
)

oth = pd.read_csv(
    f'data/itoth.txt', 
    sep = '|', 
    error_bad_lines = False, 
    header = None, 

)

oth.columns = [x.lower() for x in headers]

oth.head()
# Out:
#      cmte_id amndt_ind rpt_tp transaction_pgi           image_num  \
# 0  C00390633         N     YE           P2018  201801249090614097
# 1  C00392464         N     YE               P  201801249090614161
# 2  C00392464         N     YE               P  201801249090614161
# 3  C00392464         N     YE           P2018  201801249090614162
# 4  C00392464         N     YE           P2018  201801249090614161
#
#   transaction_tp entity_tp                               name            city  \
# 0            24K       CCM          PETE AGUILAR FOR CONGRESS  SAN BERNARDINO
# 1            24K       COM        FEARLESS FOR THE PEOPLE PAC     LOS ANGELES
# 2            24K       COM        FEARLESS FOR THE PEOPLE PAC     LOS ANGELES
# 3            24K       CCM  TED DEUTCH FOR CONGRESS COMMITTEE      WASHINGTON
# 4            24K       CCM     LEE THOMAS MILLER FOR CONGRESS        FRANKLIN
#
#   state  ... employer occupation transaction_dt  transaction_amt   other_id  \
# ...
